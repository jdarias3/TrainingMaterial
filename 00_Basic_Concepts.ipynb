# %% [markdown]
# # Python start
#
# If you are totally new with python, you are in the correct place. Let's begin
#
# In order to run python in your machine, you need to install it, you can download Python in the following link:
#
# www.python.org

# %%
a = 3
b = 3
if a+b == 6:
  print("Good answer")
else:
  print("bad answer")
# Out:
# Good answer
