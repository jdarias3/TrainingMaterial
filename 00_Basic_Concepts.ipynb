# %% [markdown]
# # Python Course
#
# If you are totally new with python, you are in the correct place.
#
# ##Let's begin with some base concepts
#
#
#
# 1.   Simple Operations
# 2.   Data Types
#
#   2.1. Integers
#
#   2.2. Floats
#
#   2.2. Strings
#
#
# In order to run python in your machine, you need to install it, you can download Python in the following link:
#
# www.python.org

# %%
a = 3
b = 3
if a+b == 6:
  print("Good answer")
else:
  print("bad answer")
